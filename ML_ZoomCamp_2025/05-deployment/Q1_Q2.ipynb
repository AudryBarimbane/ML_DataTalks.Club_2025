# %%
# !pip install uv
# Out:
# ...
#    ---------------------------------------- 0.0/21.4 MB ? eta -:--:--
#    ---------------------------------------- 0.0/21.4 MB ? eta -:--:--
#    ---------------------------------------- 0.0/21.4 MB ? eta -:--:--
#    ---------------------------------------- 0.3/21.4 MB ? eta -:--:--
#     --------------------------------------- 0.5/21.4 MB 1.2 MB/s eta 0:00:18
#    - -------------------------------------- 0.8/21.4 MB 1.6 MB/s eta 0:00:14
#    - -------------------------------------- 1.0/21.4 MB 1.5 MB/s eta 0:00:14
#    -- ------------------------------------- 1.6/21.4 MB 1.5 MB/s eta 0:00:14
#    --- ------------------------------------ 2.1/21.4 MB 1.7 MB/s eta 0:00:12
#    ---- ----------------------------------- 2.4/21.4 MB 1.7 MB/s eta 0:00:12
#    ----- ---------------------------------- 2.9/21.4 MB 1.8 MB/s eta 0:00:11
#    ------ --------------------------------- 3.4/21.4 MB 1.9 MB/s eta 0:00:10
#    ------- -------------------------------- 4.2/21.4 MB 2.0 MB/s eta 0:00:09
# ...

# %%
# !uv --version
# Out:
# uv 0.9.7 (0adb44480 2025-10-30)

# %%
# !uv init hw05
# Out:
# Initialized project `hw05` at `C:\Users\Admin-IT\Documents\audry\DSweekly\ML_DataTalks.Club_2025\ML_ZoomCamp2025\05-deployment\hw05`

# %%
# %cd hw05
# Out:
# C:\Users\Admin-IT\Documents\audry\DSweekly\ML_DataTalks.Club_2025\ML_ZoomCamp2025\05-deployment\hw05

# %%
# !uv add scikit-learn==1.6.1
# Out:
# Using CPython 3.13.9 interpreter at: C:\Users\Admin-IT\anaconda3\envs\py313\python.exe
# Creating virtual environment at: .venv
# Resolved 6 packages in 12.44s
# Prepared 5 packages in 2m 36s
# Installed 5 packages in 13.76s
#  + joblib==1.5.2
#  + numpy==2.3.4
#  + scikit-learn==1.6.1
#  + scipy==1.16.3
#  + threadpoolctl==3.6.0

# %%
with open("uv.lock", "r" , encoding="utf-8") as f:
    content = f.read()

print(content[:1000])
# Out:
# version = 1
# revision = 3
# requires-python = ">=3.13"
#
# [[package]]
# name = "hw05"
# version = "0.1.0"
# source = { virtual = "." }
# dependencies = [
#     { name = "scikit-learn" },
# ]
#
# [package.metadata]
# requires-dist = [{ name = "scikit-learn", specifier = "==1.6.1" }]
#
# [[package]]
# name = "joblib"
# version = "1.5.2"
# source = { registry = "https://pypi.org/simple" }
# sdist = { url = "https://files.pythonhosted.org/packages/e8/5d/447af5ea094b9e4c4054f82e223ada074c552335b9b4b2d14bd9b35a67c4/joblib-1.5.2.tar.gz", hash = "sha256:3faa5c39054b2f03ca547da9b2f52fde67c06240c31853f306aea97f13647b55", size = 331077, upload-time = "2025-08-27T12:15:46.575Z" }
# wheels = [
#     { url = "https://files.pythonhosted.org/packages/1e/e8/685f47e0d754320684db4425a0967f7d3fa70126bffd76110b7009a0090f/joblib-1.5.2-py3-none-any.whl", hash = "sha256:4e1f0bdbb987e6d843c70cf43714cb276623def372df3c22fe5266b2670bc241", size = 308396, upload-time = "2025-08-27T12:15:45.188Z" },
# ]
#
# ...
